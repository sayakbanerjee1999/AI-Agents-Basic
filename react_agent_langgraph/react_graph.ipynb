# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_core.agents import AgentFinish, AgentAction
from langgraph.graph import StateGraph, END

from nodes import act_node, reason_node
from react_state import AgentState

# %%
REASON_NODE = "reason_node"
ACT_NODE = "act_node"

# %%
def should_continue(state: AgentState) -> str:
    if isinstance(state["agent_outcome"], AgentFinish):
        return END
    else:
        return ACT_NODE

# %%
graph = StateGraph(AgentState)

graph.add_node(REASON_NODE, reason_node)
graph.set_entry_point(REASON_NODE)
graph.add_node(ACT_NODE, act_node)

graph.add_conditional_edges(
    REASON_NODE,
    should_continue,
)

graph.add_edge(ACT_NODE, REASON_NODE)

# %%
app = graph.compile()

result = app.invoke(
    {
        "input": "How many days ago was the latest SpaceX launch?", 
        "agent_outcome": None, 
        "intermediate_steps": []
    }
)

result
# Out:
# {'input': 'How many days ago was the latest SpaceX launch?',
#  'agent_outcome': AgentFinish(return_values={'output': 'The latest SpaceX launch was 0 days ago.'}, log='Thought: The current date is November 17, 2025, which is the same date as the latest SpaceX launch (Sentinel-6B satellite launch). Therefore, the latest SpaceX launch was today, meaning 0 days ago.  \nFinal Answer: The latest SpaceX launch was 0 days ago.'),
#  'intermediate_steps': [(AgentAction(tool='tavily_search_results_json', tool_input='latest SpaceX launch date', log='Thought: To determine how many days ago the latest SpaceX launch was, I first need to find the date of the latest SpaceX launch. After that, I will get the current date and calculate the difference in days between the two dates.\nAction: tavily_search_results_json\nAction Input: latest SpaceX launch date'),
#    '[{\'url\': \'https://www.spacex.com/launches\', \'content\': \'Upcoming launches ; Transporter-15 Mission. Falcon 9, SLC-4E, California, Droneship, November 19, 2025 10:18 - 11:15 PT ; Starlink Mission. Falcon 9, SLC-4E,\'}, {\'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'The 20-day launch window opens on July 5, 2028. Updated: April 25. News Headlines · SpaceX launches joint NASA-European sea level\'}, {\'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Sentinel-6BFalcon 9 Block 5. SpaceX · Sun · Nov 16th, 2025 9:21 PM - 9:32 PM PST. Vandenberg SFB, CA, USA ; VANHASTE. Rocket Lab · Mon · Nov 17th, 2025 7:00 AM - 10:\'}, {\'url\': \'https://rocketlaunch.org/launch-schedule/spacex\', \'content\': \'The most comprehensive, up-to-date list of upcoming SpaceX rocket launches. Search the 121 scheduled launches, with filters to easily find specific SpaceX\'}, {\'url\': \'https://www.space.com/space-exploration/launches-spacecraft/spacex-sentinel-6b-sea-level-monitoring-satellite-launch\', \'content\': "SpaceX launched a powerful ocean-mapping satellite from California early Monday morning (Nov. 17) on a landmark flight — the company\'s 500th"}]'),
#   (AgentAction(tool='get_system_time', tool_input="'%Y-%m-%d'", log="Thought: The search results mention a recent SpaceX launch of the Sentinel-6B satellite on November 17, 2025. To calculate how many days ago that was, I need to get today's date and then find the difference in days between today and November 17, 2025.\nAction: get_system_time\nAction Input: '%Y-%m-%d'"),
#    "'2025-11-17'")]}

# %%
print(result["agent_outcome"].return_values["output"], "final result")
# Out:
# The latest SpaceX launch was 0 days ago. final result
