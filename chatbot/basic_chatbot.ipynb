# %%
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import AIMessage, HumanMessage
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant"
)

# %%
class BasicChatState(TypedDict):
    messages: Annotated[list, add_messages]

def chatbot(state: BasicChatState):
    return {
        "messages": [llm.invoke(state["messages"])]
    }

# %%
graph = StateGraph(BasicChatState)

graph.add_node("chatbot", chatbot)
graph.set_entry_point("chatbot")
graph.add_edge("chatbot", END)

app = graph.compile()

# %%
while True:
    user_input = input("User: ")
    if user_input.lower() in ["end", "exit"]:
        break
    else:
        result = app.invoke({
            "messages": [HumanMessage(content=user_input)]
        })
        print(result)
# Out:
# {'messages': [HumanMessage(content="Hi, I'm Sayak", additional_kwargs={}, response_metadata={}, id='ad74d096-8dec-4c53-82e5-2deba74771d3'), AIMessage(content='Nice to meet you, Sayak. Is there something I can help you with or would you like to chat?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 41, 'total_tokens': 65, 'completion_time': 0.029770411, 'prompt_time': 0.001926432, 'queue_time': 0.075865184, 'total_time': 0.031696843}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_9ca2574dca', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--eae32403-4427-474c-95e1-949e451a423a-0', usage_metadata={'input_tokens': 41, 'output_tokens': 24, 'total_tokens': 65})]}
# {'messages': [HumanMessage(content='What is my name?', additional_kwargs={}, response_metadata={}, id='453ad0ae-6497-4a23-b945-cb7c0ac8a931'), AIMessage(content="I don't have any information about your name. I'm a large language model, I don't have the ability to retain information about individual users or keep track of their personal details. Each time you interact with me, it's a new conversation and I don't have any prior knowledge about you.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 40, 'total_tokens': 101, 'completion_time': 0.068423826, 'prompt_time': 0.002270702, 'queue_time': 0.034944288, 'total_time': 0.070694528}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_d834565e05', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--718c4f64-ec20-4696-acdd-3b054917f3cd-0', usage_metadata={'input_tokens': 40, 'output_tokens': 61, 'total_tokens': 101})]}
# {'messages': [HumanMessage(content='What is the temperature in Pittsburgh now?', additional_kwargs={}, response_metadata={}, id='32fbf7c0-a961-49e4-868d-fcd5ed86cb23'), AIMessage(content="I'm not able to access real-time information. However, I can suggest some options to find the current temperature in Pittsburgh:\n\n1. Check a weather website or app: You can visit websites like weather.com, accuweather.com, or wunderground.com for the current temperature in Pittsburgh.\n2. Use a virtual assistant: You can ask virtual assistants like Siri, Google Assistant, or Alexa to tell you the current temperature in Pittsburgh.\n3. Check a local news website: You can visit the website of a local news station in Pittsburgh, such as WPXI or KDKA, for the current weather conditions.\n4. Use a mapping app: You can use a mapping app like Google Maps or Apple Maps to get the current temperature in Pittsburgh.\n\nPlease note that the temperature may vary depending on your location within Pittsburgh, so it's a good idea to check the current temperature for your specific location.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 182, 'prompt_tokens': 43, 'total_tokens': 225, 'completion_time': 0.234014997, 'prompt_time': 0.002018173, 'queue_time': 0.076753311, 'total_time': 0.23603317}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_6b5c123dd9', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--cf8d7d34-7f87-40ec-865e-faacdd350d4b-0', usage_metadata={'input_tokens': 43, 'output_tokens': 182, 'total_tokens': 225})]}
