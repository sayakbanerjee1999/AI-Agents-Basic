# %%
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import AIMessage, HumanMessage
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.prebuilt import ToolNode

load_dotenv()
# Out:
# True

# %%
TOOL_NODE = "tool_node"
CHATBOT = "chatbot"

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant"
)

search_tool = TavilySearchResults(max_results=2)
tools = [search_tool]

llm_with_tools = llm.bind_tools(tools = tools)

# %%
class BasicChatBot(TypedDict):
    messages: Annotated[list, add_messages]

def chatbot(state: BasicChatBot):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])]
    }

# %%
def tools_router(state: BasicChatBot):
    last_message = state["messages"][-1]
    
    # AI Message is an Object and hence has attributes
    if hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0:
        return TOOL_NODE
    else:
        return END

# %%
# A node that runs the tools called in the last AIMessage.
# No need to invoke tool with the query (Handles automatically)
tool_node = ToolNode(tools = tools, messages_key = "messages")

graph = StateGraph(BasicChatBot)

graph.add_node(CHATBOT, chatbot)
graph.add_node(TOOL_NODE, tool_node)
graph.set_entry_point(CHATBOT)

graph.add_conditional_edges(CHATBOT, tools_router)
graph.add_edge(TOOL_NODE, CHATBOT)

app = graph.compile()

# %%
while True:
    user_input = input("User: ")
    if user_input.lower() in ["end", "exit"]:
        break
    else:
        result = app.invoke({
            "messages": [HumanMessage(content=user_input)]
        })
        print(result)
# Out:
# {'messages': [HumanMessage(content="Hi, I'm Sayak", additional_kwargs={}, response_metadata={}, id='1660fb71-f97a-4548-ac49-f5ca80d5abe4'), AIMessage(content="It's nice to meet you, Sayak. Is there anything I can help you with today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 284, 'total_tokens': 305, 'completion_time': 0.031554253, 'prompt_time': 0.020503523, 'queue_time': 0.005677188, 'total_time': 0.052057776}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_d834565e05', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--2379e715-0c7b-496c-9b7f-d8a6bc0cc0d2-0', usage_metadata={'input_tokens': 284, 'output_tokens': 21, 'total_tokens': 305})]}
# {'messages': [HumanMessage(content='What is the weather in Pittsburgh now?', additional_kwargs={}, response_metadata={}, id='d635ed93-460e-4291-8892-509b28d5c7fd'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'aagaaaypf', 'function': {'arguments': '{"query":"Pittsburgh weather now"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 286, 'total_tokens': 308, 'completion_time': 0.037013964, 'prompt_time': 0.021731815, 'queue_time': 0.005733762, 'total_time': 0.058745779}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_d834565e05', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--d4a5b777-1690-4fca-8a1a-8b656294b692-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Pittsburgh weather now'}, 'id': 'aagaaaypf', 'type': 'tool_call'}], usage_metadata={'input_tokens': 286, 'output_tokens': 22, 'total_tokens': 308}), ToolMessage(content='[{"url": "https://www.weather25.com/north-america/usa/pennsylvania/pittsburgh?page=month&month=November", "content": "You can expect a few days of snow in Pittsburgh during November. It’s important to get out your snow boots and warm mittens to stay warm while you explore Pittsburgh.\\n\\nOur weather forecast can give you a great sense of what weather to expect in Pittsburgh in November 2025.\\n\\nIf you’re planning to visit Pittsburgh in the near future, we highly recommend that you review the 14 day weather forecast for Pittsburgh before you arrive.\\n\\nTemperatures\\nRainy Days\\nSnowy Days\\nDry Days\\nRainfall\\n8.6 [...] The weather in Pittsburgh in November is very cold with temperatures between 2°C and 10°C, warm clothes are a must.\\n\\nYou can expect rain for roughly half of the month of November in Pittsburgh. We’re expecting roughly 8 to 15 days of rain, so your rubber boots and umbrella are going to see plenty of use this month if you’re keen on staying dry. [...] | 16 Partly cloudy 8° /2° | 17 Partly cloudy 7° /1° | 18 Overcast 3° /0° | 19 Mist 5° /-1° | 20 Fog 13° /8° | 21 Light rain shower 17° /9° | 22 Patchy rain possible 18° /11° |\\n| 23 Overcast 12° /9° | 24 Patchy rain possible 13° /6° | 25 Partly cloudy 14° /6° | 26 Light drizzle 17° /9° | 27 Patchy rain possible 19° /13° | 28 Sunny 20° /12° | 29 Patchy rain possible 20° /11° |\\n| 30 Partly cloudy 6° /2° |  |  |  |  |  |  |"}, {"url": "https://www.accuweather.com/en/us/pittsburgh/15219/november-weather/1310", "content": "# Pittsburgh, PA\\n\\nPittsburgh\\n\\nPennsylvania\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## November\\n\\n## 2025\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### December 2025 [...] ### January 2026\\n\\n### February 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWeather Forecasts\\n\\nStorminess to continue along the West coast this week\\n\\n6 hours ago\\n\\nWeather News\\n\\nFather, daughter killed after being swept into ocean in California\\n\\n1 hour ago\\n\\nWinter Weather\\n\\nSnow to streak from Dakotas, Minnesota to Pennsylvania and Maryland\\n\\n21 minutes ago\\n\\nAstronomy [...] See the ‘Golden Comet’ shatter into 3 pieces after brush with sun\\n\\n3 hours ago\\n\\nWeather Forecasts\\n\\nHeavy rain looms for south-central US, easing drought with flood risk\\n\\n6 hours ago\\n\\nFeatured Stories\\n\\nWeather N ...
